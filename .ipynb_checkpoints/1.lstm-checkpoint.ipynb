# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import model
from datetime import datetime
from datetime import timedelta
import requests
import urllib
import lxml
from bs4 import BeautifulSoup
from bs4 import NavigableString
# sns.set()

# %%
url="https://finance.yahoo.com/quote/PDNI.KL/history?p=PDNI.KL"
request = requests.get(url)
soup = BeautifulSoup(request.text, 'html.parser')
table_big = soup.find('table', attrs={'data-test':'historical-prices'})
soup.find('tfoot').decompose()

# %%
print(table_big)
# Out:
# <table class="W(100%) M(0)" data-reactid="31" data-test="historical-prices"><thead data-reactid="32"><tr class="C($c-fuji-grey-j) Fz(xs) Ta(end)" data-reactid="33"><th class="Ta(start) W(100px) Fw(400) Py(6px)" data-reactid="34"><span data-reactid="35">Date</span></th><th class="Fw(400) Py(6px)" data-reactid="36"><span data-reactid="37">Open</span></th><th class="Fw(400) Py(6px)" data-reactid="38"><span data-reactid="39">High</span></th><th class="Fw(400) Py(6px)" data-reactid="40"><span data-reactid="41">Low</span></th><th class="Fw(400) Py(6px)" data-reactid="42"><span data-reactid="43">Close*</span></th><th class="Fw(400) Py(6px)" data-reactid="44"><span data-reactid="45">Adj Close**</span></th><th class="Fw(400) Py(6px)" data-reactid="46"><span data-reactid="47">Volume</span></th></tr></thead><tbody data-reactid="48"><tr class="BdT Bdc($c-fuji-grey-c) Ta(end) Fz(s) Whs(nw)" data-reactid="49"><td class="Py(10px) Ta(start) Pend(10px)" data-reactid="50"><span data-reactid="51">Nov 05, 2018</span></td><td class="Py(10px) Pstart(10px)" data-reactid="52"><span data-reactid="53">5.55</span></td><td class="Py(10px) Pstart(10px)" data-reactid="54"><span data-reactid="55">5.56</span></td><td class="Py(10px) Pstart(10px)" data-reactid="56"><span data-reactid="57">5.40</span></td><td class="Py(10px) Pstart(10px)" data-reactid="58"><span data-reactid="59">5.51</span></td><td class="Py(10px) Pstart(10px)" data-reactid="60"><span data-reactid="61">5.51</span></td><td class="Py(10px) Pstart(10px)" data-reactid="62"><span data-reactid="63">46,400</span></td></tr><tr class="BdT Bdc($c-fuji-grey-c) Ta(end) Fz(s) Whs(nw)" data-reactid="64"><td class="Py(10px) Ta(start) Pend(10px)" data-reactid="65"><span data-reactid="66">May 07, 2018</span></td><td class="Py(10px) Pstart(10px)" data-reactid="67"><span data-reactid="68">4.50</span></td><td class="Py(10px) Pstart(10px)" data-reactid="69"><span data-reactid="70">4.52</span></td><td class="Py(10px) Pstart(10px)" data-reactid="71"><span data-reactid="72">4.38</span></td><td class="Py(10px) Pstart(10px)" data-reactid="73"><span data-reactid="74">4.50</span></td><td class="Py(10px) Pstart(10px)" data-reactid="75"><span data-reactid="76">4.50</span></td><td class="Py(10px) Pstart(10px)" data-reactid="77"><span data-reactid="78">750,900</span></td></tr><tr class="BdT Bdc($c-fuji-grey-c) Ta(end) Fz(s) Whs(nw)" data-reactid="79"><td class="Py(10px) Ta(start) Pend(10px)" data-reactid="80"><span data-reactid="81">May 04, 2018</span></td><td class="Py(10px) Pstart(10px)" data-reactid="82"><span data-reactid="83">4.44</span></td><td class="Py(10px) Pstart(10px)" data-reactid="84"><span data-reactid="85">4.52</span></td><td class="Py(10px) Pstart(10px)" data-reactid="86"><span data-reactid="87">4.44</span></td><td class="Py(10px) Pstart(10px)" data-reactid="88"><span data-reactid="89">4.50</span></td><td class="Py(10px) Pstart(10px)" data-reactid="90"><span data-reactid="91">4.50</span></td><td class="Py(10px) Pstart(10px)" data-reactid="92"><span data-reactid="93">2,905,200</span></td></tr><tr class="BdT Bdc($c-fuji-grey-c) Ta(end) Fz(s) Whs(nw)" data-reactid="94"><td class="Py(10px) Ta(start) Pend(10px)" data-reactid="95"><span data-reactid="96">May 03, 2018</span></td><td class="Py(10px) Pstart(10px)" data-reactid="97"><span data-reactid="98">4.33</span></td><td class="Py(10px) Pstart(10px)" data-reactid="99"><span data-reactid="100">4.50</span></td><td class="Py(10px) Pstart(10px)" data-reactid="101"><span data-reactid="102">4.28</span></td><td class="Py(10px) Pstart(10px)" data-reactid="103"><span data-reactid="104">4.44</span></td><td class="Py(10px) Pstart(10px)" data-reactid="105"><span data-reactid="106">4.44</span></td><td class="Py(10px) Pstart(10px)" data-reactid="107"><span data-reactid="108">395,600</span></td></tr><tr class="BdT Bdc($c-fuji-grey-c) Ta(end) Fz(s) Whs(nw)" data-reactid="109"><td class="Py(10px) Ta(start) Pend(10px)" data-reactid="110"><span data-reactid="111">May 02, 2018</span ...

# %%
rs = pd.read_html(str(table_big))
rs = rs[0].to_json(orient='records')
print(rs)
# Out:
# [{"Date":"Nov 05, 2018","Open":"5.55","High":"5.56","Low":"5.40","Close*":"5.51","Adj Close**":"5.51","Volume":"46400"},{"Date":"May 07, 2018","Open":"4.50","High":"4.52","Low":"4.38","Close*":"4.50","Adj Close**":"4.50","Volume":"750900"},{"Date":"May 04, 2018","Open":"4.44","High":"4.52","Low":"4.44","Close*":"4.50","Adj Close**":"4.50","Volume":"2905200"},{"Date":"May 03, 2018","Open":"4.33","High":"4.50","Low":"4.28","Close*":"4.44","Adj Close**":"4.44","Volume":"395600"},{"Date":"May 02, 2018","Open":"4.36","High":"4.36","Low":"4.20","Close*":"4.26","Adj Close**":"4.26","Volume":"1510400"},{"Date":"Apr 30, 2018","Open":"4.39","High":"4.41","Low":"4.21","Close*":"4.25","Adj Close**":"4.25","Volume":"334000"},{"Date":"Apr 27, 2018","Open":"4.42","High":"4.42","Low":"4.35","Close*":"4.38","Adj Close**":"4.38","Volume":"206000"},{"Date":"Apr 26, 2018","Open":"4.50","High":"4.51","Low":"4.39","Close*":"4.39","Adj Close**":"4.39","Volume":"81100"},{"Date":"Apr 25, 2018","Open":"4.44","High":"4.50","Low":"4.42","Close*":"4.50","Adj Close**":"4.50","Volume":"19500"},{"Date":"Apr 24, 2018","Open":"4.50","High":"4.63","Low":"4.46","Close*":"4.55","Adj Close**":"4.55","Volume":"51600"},{"Date":"Apr 23, 2018","Open":"4.64","High":"4.64","Low":"4.55","Close*":"4.55","Adj Close**":"4.55","Volume":"381000"},{"Date":"Apr 20, 2018","Open":"4.60","High":"4.64","Low":"4.58","Close*":"4.64","Adj Close**":"4.64","Volume":"429300"},{"Date":"Apr 19, 2018","Open":"4.53","High":"4.60","Low":"4.53","Close*":"4.60","Adj Close**":"4.60","Volume":"36900"},{"Date":"Apr 18, 2018","Open":"4.52","High":"4.57","Low":"4.47","Close*":"4.55","Adj Close**":"4.55","Volume":"158200"},{"Date":"Apr 17, 2018","Open":"4.59","High":"4.62","Low":"4.52","Close*":"4.57","Adj Close**":"4.57","Volume":"136600"},{"Date":"Apr 16, 2018","Open":"4.52","High":"4.65","Low":"4.50","Close*":"4.51","Adj Close**":"4.51","Volume":"253000"},{"Date":"Apr 13, 2018","Open":"4.80","High":"4.80","Low":"4.50","Close*":"4.50","Adj Close**":"4.50","Volume":"170500"},{"Date":"Apr 12, 2018","Open":"4.80","High":"4.80","Low":"4.55","Close*":"4.75","Adj Close**":"4.75","Volume":"115500"},{"Date":"Apr 11, 2018","Open":"4.69","High":"4.81","Low":"4.68","Close*":"4.80","Adj Close**":"4.80","Volume":"1903900"},{"Date":"Apr 10, 2018","Open":"4.51","High":"4.69","Low":"4.51","Close*":"4.65","Adj Close**":"4.65","Volume":"615700"},{"Date":"Apr 09, 2018","Open":"4.60","High":"4.64","Low":"4.40","Close*":"4.61","Adj Close**":"4.61","Volume":"172600"},{"Date":"Apr 06, 2018","Open":"4.55","High":"4.65","Low":"4.46","Close*":"4.60","Adj Close**":"4.60","Volume":"715200"},{"Date":"Apr 05, 2018","Open":"4.42","High":"4.57","Low":"4.39","Close*":"4.55","Adj Close**":"4.55","Volume":"447600"},{"Date":"Apr 04, 2018","Open":"4.49","High":"4.49","Low":"4.37","Close*":"4.47","Adj Close**":"4.47","Volume":"2151300"},{"Date":"Apr 03, 2018","Open":"4.39","High":"4.52","Low":"4.36","Close*":"4.49","Adj Close**":"4.49","Volume":"1221500"},{"Date":"Apr 02, 2018","Open":"4.41","High":"4.48","Low":"4.35","Close*":"4.41","Adj Close**":"4.41","Volume":"1148700"},{"Date":"Mar 30, 2018","Open":"4.40","High":"4.47","Low":"4.31","Close*":"4.47","Adj Close**":"4.47","Volume":"442600"},{"Date":"Mar 29, 2018","Open":"4.40","High":"4.40","Low":"4.25","Close*":"4.35","Adj Close**":"4.35","Volume":"324600"},{"Date":"Mar 28, 2018","Open":"4.45","High":"4.45","Low":"4.37","Close*":"4.40","Adj Close**":"4.40","Volume":"1950900"},{"Date":"Mar 27, 2018","Open":"4.29","High":"4.49","Low":"4.26","Close*":"4.44","Adj Close**":"4.44","Volume":"2481200"},{"Date":"Mar 26, 2018","Open":"4.47","High":"4.47","Low":"4.13","Close*":"4.24","Adj Close**":"4.24","Volume":"1712600"},{"Date":"Mar 23, 2018","Open":"4.47","High":"4.47","Low":"4.37","Close*":"4.45","Adj Close**":"4.45","Volume":"2391200"},{"Date":"Mar 22, 2018","Open":"4.47","High":"4.56","Low":"4.42","Close*":"4.54","Adj Close**":"4.54","Volume":"1117500"},{"Date":"Mar 21, 2018","Open":"4. ...

# %%
df = pd.read_json(rs)

# %%
df = df[['Date','Open','High','Low','Close*','Adj Close**']]
df = df.sort_values(by='Date', ascending=1)
date_ori = pd.to_datetime(df.iloc[:, 0]).tolist()
dfori = df.apply(pd.to_numeric, args=('coerce',))
df.head()
# Out:
#          Date  Open  High   Low Close* Adj Close**
# 99 2017-12-14  5.38  5.40  5.27   5.38        5.38
# 98 2017-12-15  5.35  5.50  5.32   5.46        5.46
# 97 2017-12-18  5.46  5.50  5.43   5.46        5.46
# 96 2017-12-19  5.43  5.48  5.27   5.33        5.33
# 95 2017-12-20  5.33  5.40  5.21   5.34        5.34

# %%
df = df[df.Low != '-']
minmax = MinMaxScaler().fit(df.iloc[:, 1:].astype('float32'))
# Out:
# C:\Users\amirieiybah\AppData\Local\conda\conda\envs\finalYearProject\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype float32 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
minmax.transform(df.iloc[:, 1:].astype('float32'))
# Out:
# array([[0.86507933, 0.86666677, 0.87692317, 0.89763774, 0.89763774],
#        [0.84126964, 0.95000004, 0.91538486, 0.96062979, 0.96062979],
#        [0.92857132, 0.95000004, 1.        , 0.96062979, 0.96062979],
#        [0.90476163, 0.93333339, 0.87692317, 0.85826753, 0.85826753],
#        [0.82539665, 0.86666677, 0.83076935, 0.86614172, 0.86614172],
#        [0.82539665, 0.82499994, 0.83846147, 0.85826753, 0.85826753],
#        [0.83333333, 0.81666681, 0.85384608, 0.79527548, 0.79527548],
#        [0.76190465, 0.74166667, 0.86153856, 0.79527548, 0.79527548],
#        [0.76190465, 0.74166667, 0.81538475, 0.75590527, 0.75590527],
#        [0.72222197, 0.79166663, 0.81538475, 0.8346457 , 0.8346457 ],
#        [0.80158734, 0.78333351, 0.83076935, 0.81889769, 0.81889769],
#        [0.76984134, 0.78333351, 0.86923105, 0.81889769, 0.81889769],
#        [0.80158734, 0.78333351, 0.78461554, 0.75590527, 0.75590527],
#        [0.72222197, 0.80833329, 0.79230766, 0.84251952, 0.84251952],
#        [0.80952365, 0.79166663, 0.82307687, 0.77952747, 0.77952747],
#        [0.75396797, 0.85000012, 0.82307687, 0.88188973, 0.88188973],
#        [0.84920633, 0.85000012, 0.86923105, 0.87401554, 0.87401554],
#        [0.84126964, 0.82499994, 0.86923105, 0.81889769, 0.81889769],
#        [0.80158734, 0.78333351, 0.86923105, 0.81889769, 0.81889769],
#        [0.80158734, 0.82499994, 0.86923105, 0.85039371, 0.85039371],
#        [0.79365065, 0.77499998, 0.82307687, 0.77952747, 0.77952747],
#        [0.76190465, 0.78333351, 0.76923094, 0.8346457 , 0.8346457 ],
#        [0.80158734, 0.78333351, 0.80000015, 0.82677151, 0.82677151],
#        [0.74603166, 0.7500002 , 0.76153845, 0.75590527, 0.75590527],
#        [0.73015866, 0.74166667, 0.76153845, 0.79527548, 0.79527548],
#        [0.75396797, 0.73333315, 0.76153845, 0.71653543, 0.71653543],
#        [0.69047597, 0.67500006, 0.74615385, 0.71653543, 0.71653543],
#        [0.65872998, 0.69166671, 0.76153845, 0.74803145, 0.74803145],
#        [0.67460298, 0.64999988, 0.74615385, 0.68503941, 0.68503941],
#        [0.69047597, 0.66666653, 0.69230792, 0.6614172 , 0.6614172 ],
#        [0.61904767, 0.60833345, 0.70000004, 0.6692914 , 0.6692914 ],
#        [0.63492067, 0.65833341, 0.70000004, 0.71653543, 0.71653543],
#        [0.64285698, 0.61666657, 0.71538464, 0.6692914 , 0.6692914 ],
#        [0.63492067, 0.69166671, 0.72307713, 0.74803145, 0.74803145],
#        [0.69841266, 0.69999984, 0.74615385, 0.73228344, 0.73228344],
#        [0.57936499, 0.55833349, 0.63076913, 0.59842516, 0.59842516],
#        [0.56349199, 0.61666657, 0.66923083, 0.6614172 , 0.6614172 ],
#        [0.57142868, 0.57500014, 0.66923083, 0.63779538, 0.63779538],
#        [0.56349199, 0.53333331, 0.55384611, 0.55118113, 0.55118113],
#        [0.531746  , 0.59166679, 0.58461532, 0.62992118, 0.62992118],
#        [0.63492067, 0.60833345, 0.69230792, 0.62992118, 0.62992118],
#        [0.57936499, 0.61666657, 0.63846162, 0.59842516, 0.59842516],
#        [0.56349199, 0.74166667, 0.66923083, 0.79527548, 0.79527548],
#        [0.73015866, 0.78333351, 0.75384633, 0.70866124, 0.70866124],
#        [0.67460298, 0.69999984, 0.70000004, 0.64566919, 0.64566919],
#        [0.60317468, 0.63333323, 0.70000004, 0.62992118, 0.62992118],
#        [0.58730168, 0.56666661, 0.66923083, 0.60629935, 0.60629935],
#        [0.57936499, 0.65833341, 0.68461543, 0.71653543, 0.71653543],
#        [0.65079367, 0.82499994, 0.72307713, 0.87401554, 0.87401554],
#        [0.72222197, 0.69999984, 0.72307713, 0.70078742, 0.70078742],
#        [0.68253966, 0.68333319, 0.53076939, 0.56692914, 0.56692914],
#        [0.531746  , 0.53333331, 0.52307691, 0.59842516, 0.59842516],
#        [0.56349199, 0.61666657, 0.60769241, 0.65354339, 0.65354339],
#        [0.62698398, 0.59999992, 0.59999993, 0.6614172 , 0.6614172 ],
#        [0.60317468, 0.61666657, 0.63846162, 0.67716522, 0.67716522],
#        [0.62698398, 0.61666657, 0.59999993, 0.67716522, 0.67716522],
#        [0.56349199, 0.61666657, 0.66923083, 0.65354339, 0.65354339],
#        [0.61111098, 0.59166679, 0.61538453, 0.63779538, 0.63779538],
#        [0.57142868, 0.58333327, 0.64615374, 0.60629935, 0.60629935],
#        [0.57142868, 0.54166683, 0.39230759, 0.40944903, 0.40944903],
#        [0.38095233, 0.46666669, 0.4923077 , 0.48031489, 0.48031489],
#        [0.468254  , 0.45833317, 0.46153849, 0.4960629 , 0.4960629 ],
#        [0.40476201, 0.36666677, 0.4384614 , 0.36220462, 0.36220462],
#        [0.32539665, 0.30833329, 0.38461547, 0.3385828 , 0.3385828 ],
#        [0.30158734, 0.25833333, 0.26923076, 0.25196855, 0.25196855],
#        [0.19841266, 0.19999984, 0.25384615, 0.18110231, 0.18110231],
#        [0.14285698, 0.16666653, 0.22307694, 0.23622054, 0.23622054],
#        [0.14285698, 0.0916664 , 0.18461525, 0.1653543 , 0.1653543 ],
#        [0.14285698, 0.0916664 , 0.        , 0.        , 0.        ],
#        [0.        , 0.10833305, 0.10000011, 0.15748048, 0.15748048],
#        [0.12698398, 0.07499974, 0.18461525, 0.12598446, 0.12598446],
#        [0.08730168, 0.03333331, 0.09230762, 0.08661425, 0.08661425],
#        [0.08730168, 0.0916664 , 0.13846144, 0.18110231, 0.18110231],
#        [0.09523799, 0.09999992, 0.16923065, 0.13385828, 0.13385828],
#        [0.07936499, 0.13333323, 0.17692313, 0.19685032, 0.19685032],
#        [0.15872998, 0.10833305, 0.18461525, 0.18110231, 0.18110231],
#        [0.10317468, 0.17500006, 0.19999985, 0.24409473, 0.24409473],
#        [0.20634935, 0.24166667, 0.25384615, 0.28346457, 0.28346457],
#        [0.24603166, 0.23333315, 0.20769234, 0.29133876, 0.29133876],
#        [0.17460335, 0.27499998, 0.29230784, 0.32283478, 0.32283478],
#        [0.31746034, 0.3749999 , 0.4230768 , 0.44094505, 0.44094505],
#        [0.40476201, 0.36666677, 0.32307705, 0.40157484, 0.40157484],
#        [0.40476201, 0.36666677, 0.28461536, 0.20472452, 0.20472452],
#        [0.18253966, 0.24166667, 0.28461536, 0.21259871, 0.21259871],
#        [0.23809535, 0.21666649, 0.29999996, 0.25984274, 0.25984274],
#        [0.18253966, 0.17500006, 0.26153827, 0.24409473, 0.24409473],
#        [0.19047635, 0.19999984, 0.30769245, 0.28346457, 0.28346457],
#        [0.24603166, 0.23333315, 0.34615378, 0.31496059, 0.31496059],
#        [0.27777765, 0.23333315, 0.32307705, 0.24409473, 0.24409473],
#        [0.16666667, 0.22500002, 0.25384615, 0.24409473, 0.24409473],
#        [0.11904767, 0.11666657, 0.22307694, 0.20472452, 0.20472452],
#        [0.16666667, 0.1250001 , 0.19999985, 0.11811027, 0.11811027],
#        [0.10317468, 0.04999996, 0.16923065, 0.11023645, 0.11023645],
#        [0.07936499, 0.04166643, 0.06153842, 0.00787419, 0.00787419],
#        [0.05555568, 0.        , 0.05384593, 0.01574839, 0.01574839],
#        [0.031746  , 0.11666657, 0.11538471, 0.15748048, 0.15748048],
#        [0.11904767, 0.13333323, 0.23846155, 0.20472452, 0.20472452],
#        [0.16666667, 0.13333323, 0.19230773, 0.20472452, 0.20472452],
#        [1.        , 1.        , 0.97692328, 1.        , 1.        ]])

# %%
minmax = MinMaxScaler().fit(df.iloc[:, 1:].astype('float32'))
df_log = minmax.transform(df.iloc[:, 1:].astype('float32'))
df_log = pd.DataFrame(df_log)
df_log.head()
# Out:
# C:\Users\amirieiybah\AppData\Local\conda\conda\envs\finalYearProject\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype float32 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#           0         1         2         3         4
# 0  0.865079  0.866667  0.876923  0.897638  0.897638
# 1  0.841270  0.950000  0.915385  0.960630  0.960630
# 2  0.928571  0.950000  1.000000  0.960630  0.960630
# 3  0.904762  0.933333  0.876923  0.858268  0.858268
# 4  0.825397  0.866667  0.830769  0.866142  0.866142

# %%
num_layers = 1
size_layer = 128
timestamp = 7
epoch = 500
dropout_rate = 0.7
future_day = 50

# %%
tf.reset_default_graph()
modelnn = model.Model(0.01, num_layers, df_log.shape[1], size_layer, df_log.shape[1], dropout_rate)
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())
for i in range(epoch):
    init_value = np.zeros((1, num_layers * 2 * size_layer))
    total_loss = 0
    for k in range(0, (df_log.shape[0] // timestamp) * timestamp, timestamp):
        batch_x = np.expand_dims(df_log.iloc[k: k + timestamp, :].values, axis = 0)
        batch_y = df_log.iloc[k + 1: k + timestamp + 1, :].values
        last_state, _, loss = sess.run([modelnn.last_state, 
                                        modelnn.optimizer, 
                                        modelnn.cost], feed_dict={modelnn.X: batch_x, 
                                                                  modelnn.Y: batch_y, 
                                                                  modelnn.hidden_layer: init_value})
        loss = np.mean(loss)
        init_value = last_state
        total_loss += loss
    total_loss /= (df_log.shape[0] // timestamp)
    if (i + 1) % 100 == 0:
        print('epoch:', i + 1, 'avg loss:', total_loss)
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000029A8B1124E0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# epoch: 100 avg loss: 0.019654836572174515
# epoch: 200 avg loss: 0.015963097102940083
# epoch: 300 avg loss: 0.007267722610517272
# epoch: 400 avg loss: 0.004514708898828498
# epoch: 500 avg loss: 0.0042257348042247555

# %%
output_predict = np.zeros((df_log.shape[0] + future_day, df_log.shape[1]))
output_predict[0, :] = df_log.iloc[0, :]
upper_b = (df_log.shape[0] // timestamp) * timestamp
init_value = np.zeros((1, num_layers * 2 * size_layer))
for k in range(0, (df_log.shape[0] // timestamp) * timestamp, timestamp):
    out_logits, last_state = sess.run([modelnn.logits, modelnn.last_state], feed_dict = {modelnn.X:np.expand_dims(df_log.iloc[k: k + timestamp, :], axis = 0),
                                     modelnn.hidden_layer: init_value})
    init_value = last_state
    output_predict[k + 1: k + timestamp + 1, :] = out_logits
    
out_logits, last_state = sess.run([modelnn.logits, modelnn.last_state], feed_dict = {modelnn.X:np.expand_dims(df_log.iloc[upper_b: , :], axis = 0),
                                     modelnn.hidden_layer: init_value})
init_value = last_state
output_predict[upper_b + 1: df_log.shape[0] + 1, :] = out_logits
df_log.loc[df_log.shape[0]] = out_logits[-1, :]
date_ori.append(date_ori[-1]+timedelta(days=1))

# %%
for i in range(future_day - 1):
    out_logits, last_state = sess.run([modelnn.logits, modelnn.last_state], feed_dict = {modelnn.X:np.expand_dims(df_log.iloc[-timestamp:, :], axis = 0),
                                     modelnn.hidden_layer: init_value})
    init_value = last_state
    output_predict[df_log.shape[0], :] = out_logits[-1, :]
    df_log.loc[df_log.shape[0]] = out_logits[-1, :]
    date_ori.append(date_ori[-1]+timedelta(days=1))

# %%
df_log = minmax.inverse_transform(output_predict)
date_ori=pd.Series(date_ori).dt.strftime(date_format='%Y-%m-%d').tolist()

# %%
# current_palette = sns.color_palette("Paired", 12)
dfori4 = dfori.iloc[:, 4].astype(float)
fig = plt.figure(figsize = (15,10))
ax = plt.subplot(111)
x_range_original = np.arange(dfori.shape[0])
x_range_future = np.arange(df_log.shape[0])
# ax.plot(x_range_original, df.iloc[:, 1], label = 'true Open' )
# ax.plot(x_range_future, df_log[:, 0], label = 'predict Open')
# ax.plot(x_range_original, df.iloc[:, 2], label = 'true High')
# ax.plot(x_range_future, df_log[:, 1], label = 'predict High')
# ax.plot(x_range_original, df.iloc[:, 3], label = 'true Low')
# ax.plot(x_range_future, df_log[:, 2], label = 'predict Low')
ax.plot(x_range_original, dfori.iloc[:, 4], label = 'true Close')
ax.plot(x_range_future, df_log[:, 3], label = 'predict Close')
# ax.plot(x_range_original, df.iloc[:, 5], label = 'true Adj Close')
# ax.plot(x_range_future, df_log[:, 4], label = 'predict Adj Close')
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1, box.width, box.height * 0.9])
ax.legend(loc = 'upper center', bbox_to_anchor= (0.5, -0.05), fancybox = True, shadow = True, ncol = 5)
plt.title('overlap stock market')
plt.xticks(x_range_future[::15], date_ori[::15])
plt.show()

# %%
dfori.iloc[:, 2]
# Out:
# 99    5.40
# 98    5.50
# 97    5.50
# 96    5.48
# 95    5.40
# 94    5.35
# 93    5.34
# 92    5.25
# 91    5.25
# 90    5.31
# 89    5.30
# 88    5.30
# 87    5.30
# 86    5.33
# 85    5.31
# 84    5.38
# 83    5.38
# 82    5.35
# 81    5.30
# 80    5.35
# 79    5.29
# 78    5.30
# 77    5.30
# 76    5.26
# 75    5.25
# 74    5.24
# 73    5.17
# 72    5.19
# 71    5.14
# 70    5.16
#       ...
# 29    4.49
# 28    4.45
# 27    4.40
# 26    4.47
# 25    4.48
# 24    4.52
# 23    4.49
# 22    4.57
# 21    4.65
# 20    4.64
# 19    4.69
# 18    4.81
# 17    4.80
# 16    4.80
# 15    4.65
# 14    4.62
# 13    4.57
# 12    4.60
# 11    4.64
# 10    4.64
# 9     4.63
# 8     4.50
# 7     4.51
# 6     4.42
# 5     4.41
# 4     4.36
# 3     4.50
# 2     4.52
# 1     4.52
# 0     5.56
# Name: High, Length: 100, dtype: float64

# %%
fig = plt.figure(figsize = (20,8))
plt.subplot(1, 2, 1)
plt.plot(x_range_original, df.iloc[:, 1], label = 'true Open', color = current_palette[0])
plt.plot(x_range_original, df.iloc[:, 2], label = 'true High', color = current_palette[2])
plt.plot(x_range_original, df.iloc[:, 3], label = 'true Low', color = current_palette[4])
plt.plot(x_range_original, df.iloc[:, 4], label = 'true Close', color = current_palette[6])
plt.plot(x_range_original, df.iloc[:, 5], label = 'true Adj Close', color = current_palette[8])
plt.xticks(x_range_original[::60], df.iloc[:, 0].tolist()[::60])
plt.legend()
plt.title('true market')
plt.subplot(1, 2, 2)
plt.plot(x_range_future, df_log[:, 0], label = 'predict Open', color = current_palette[1])
plt.plot(x_range_future, df_log[:, 1], label = 'predict High', color = current_palette[3])
plt.plot(x_range_future, df_log[:, 2], label = 'predict Low', color = current_palette[5])
plt.plot(x_range_future, df_log[:, 3], label = 'predict Close', color = current_palette[7])
plt.plot(x_range_future, df_log[:, 4], label = 'predict Adj Close', color = current_palette[9])
plt.xticks(x_range_future[::60], date_ori[::60])
plt.legend()
plt.title('predict market')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-692b37454cc1> in <module>
#       1 fig = plt.figure(figsize = (20,8))
#       2 plt.subplot(1, 2, 1)
# ----> 3 plt.plot(x_range_original, df.iloc[:, 1], label = 'true Open', color = current_palette[0])
#       4 plt.plot(x_range_original, df.iloc[:, 2], label = 'true High', color = current_palette[2])
#       5 plt.plot(x_range_original, df.iloc[:, 3], label = 'true Low', color = current_palette[4])
#
# NameError: name 'current_palette' is not defined

# %%
fig = plt.figure(figsize = (15,10))
ax = plt.subplot(111)
ax.plot(x_range_original, df.iloc[:, -1], label = 'true Volume')
ax.plot(x_range_future, df_log[:, -1], label = 'predict Volume')
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1, box.width, box.height * 0.9])
ax.legend(loc = 'upper center', bbox_to_anchor= (0.5, -0.05), fancybox = True, shadow = True, ncol = 5)
plt.xticks(x_range_future[::30], date_ori[::30])
plt.title('overlap market volume')
plt.show()

# %%
fig = plt.figure(figsize = (20,8))
plt.subplot(1, 2, 1)
plt.plot(x_range_original, df.iloc[:, -1], label = 'true Volume')
plt.xticks(x_range_original[::60], df.iloc[:, 0].tolist()[::60])
plt.legend()
plt.title('true market volume')
plt.subplot(1, 2, 2)
plt.plot(x_range_future, df_log[:, -1], label = 'predict Volume')
plt.xticks(x_range_future[::60], date_ori[::60])
plt.legend()
plt.title('predict market volume')
plt.show()
